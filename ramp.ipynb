# %%
import numpy as np
import matplotlib.pyplot as plt

# r(t)= 0 when t<0 else r(t)=t

# %%
T=np.arange(-10,10)
R=np.where(T>=0,T,0)

plt.plot(T,R)
plt.xlabel('t')
plt.ylabel('r(t)')
plt.title('r(t)= 0 when t<0 else r(t)=t')
plt.show()
