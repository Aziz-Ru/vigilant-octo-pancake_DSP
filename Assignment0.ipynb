# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def unit_step(x):
    return np.where(x>=4,1,0)

# %%
t=np.linspace(-10,10,100)
y=np.arange(0,100, 5)

# %%
def sine_wave(A, f, t):
    return A*np.sin(2*np.pi*f*t)

# %%
plt.plot(sine_wave(5,10,t)[20:])
plt.title('Unit Step Function')
plt.grid()
plt.show()
