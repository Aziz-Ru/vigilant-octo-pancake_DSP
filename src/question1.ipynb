# %%
import numpy as np
import matplotlib.pyplot as plt



n=np.arange(-20,20,1)

unit_step_y= np.where(n>=0, 1, 0)
unit_impulse =np.where(n==0,1,0)
ramp= np.where(n>=0,n,0)

exponential = np.exp(-0.1*n)


plt.figure(figsize=(20, 15))

plt.subplot(3,2,1)
plt.plot(n,dft.real)
plt.title('Signal qa1')
plt.subplot(3,2,1)
plt.stem(n,unit_impulse)
plt.title('Unit Impulse Function')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.grid()

plt.subplot(3,2,2)
plt.stem(n,unit_step_y)
plt.title('Unit Step Function')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.grid()

plt.subplot(3,2,3)
plt.stem(n,ramp)
plt.title('Ramp Function')
plt.xlabel('n')
plt.ylabel('Amplitude')

plt.subplot(3,2,4)
plt.stem(n,exponential)
plt.title('Exponential Function')
plt.xlabel('n')
plt.ylabel('Amplitude')
plt.grid()
